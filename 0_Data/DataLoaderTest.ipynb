# %%
#librerías, no es necesario volverlas a importar
import os
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.utils import compute_class_weight

util = os.path.join('..','0_Data','Util.ipynb')
#Vectorizacion
# %run $util
# Out:
# [nltk_data] Downloading package punkt to /home/celeste/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/celeste/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/celeste/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df_train = pd.read_csv(os.path.join('..','dataset','train.csv'),index_col='id', encoding='utf8')
df_test = pd.read_csv(os.path.join('..','dataset','test.csv'),index_col='id', encoding='utf8')

df_train['keyword'] = df_train['keyword'].fillna('')
df_train['location']= df_train['location'].fillna('')

df_train['concat '] = df_train['location'].astype(str) + ' '+df_train['keyword'].astype(str) +' ' +  df_train['text']

temp_df, test_data = train_test_split(df_train, test_size=0.2, random_state=1, shuffle=True, stratify=df_train.target)
train_data, val_data = train_test_split(temp_df, test_size=0.2, random_state=2, shuffle=True, stratify=temp_df.target)

class datos_originales_como_arrays:
    def __init__(self):
        self.x_train = train_data.text
        self.y_train = train_data.target
        self.x_val = val_data.text
        self.y_val = val_data.target
        self.x_test = test_data.text
        self.y_test = test_data.target
        self.predict = df_test.text
#Devolver los datos como arrays
def get_data_original_as_np_array():    
    return datos_originales_como_arrays()

# %%
df_train.head(50)
# Out:
#    keyword                       location  \
# id
# 1
# 4
# 5
# 6
# 7
# 8
# 10
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 20
# 23
# 24
# 25
# 26
# 28
# 31
# 32
# 33
# 34
# 36
# 37
# 38
# 39
# 40
# 41
# 44
# 48  ablaze                     Birmingham
# 49  ablaze  Est. September 2012 - Bristol
# 50  ablaze                         AFRICA
# 52  ablaze               Philadelphia, PA
# 53  ablaze                     London, UK
# 54  ablaze                       Pretoria
# 55  ablaze                   World Wide!!
# 56  ablaze
# 57  ablaze                 Paranaque City
# 59  ablaze                 Live On Webcam
# 61  ablaze
# 62  ablaze                      milky way
# 63  ablaze
# 64  ablaze
# 65  ablaze
# 66  ablaze      GREENSBORO,NORTH CAROLINA
# 67  ablaze
# 68  ablaze                 Live On Webcam
# 71  ablaze                       England.
#
#                                                  text  target  \
# id
# 1   Our Deeds are the Reason of this #earthquake M...       1
# 4              Forest fire near La Ronge Sask. Canada       1
# 5   All residents asked to 'shelter in place' are ...       1
# 6   13,000 people receive #wildfires evacuation or...       1
# 7   Just got sent this photo from Ruby #Alaska as ...       1
# 8   #RockyFire Update => California Hwy. 20 closed...       1
# 10  #flood #disaster Heavy rain causes flash flood...       1
# 13  I'm on top of the hill and I can see a fire in...       1
# 14  There's an emergency evacuation happening now ...       1
# 15  I'm afraid that the tornado is coming to our a...       1
# 16        Three people died from the heat wave so far       1
# 17  Haha South Tampa is getting flooded hah- WAIT ...       1
# 18  #raining #flooding #Florida #TampaBay #Tampa 1...       1
# 19            #Flood in Bago Myanmar #We arrived Bago       1
# 20  Damage to school bus on 80 in multi car crash ...       1
# 23                                     What's up man?       0
# 24                                      I love fruits       0
# 25                                   Summer is lovely       0
# 26                                  My car is so fast       0
# 28                       What a goooooooaaaaaal!!!!!!       0
# 31                             this is ridiculous....       0
# 32                                  London is cool ;)       0
# 33                                        Love skiing       0
# 34                              What a wonderful day!       0
# 36                                           LOOOOOOL       0
# 37                     No way...I can't eat that shit       0
# 38                              Was in NYC last week!       0
# 39                                 Love my girlfriend       0
# 40                                          Cooool :)       0
# 41                                 Do you like pasta?       0
# 44                                           The end!       0
# 48  @bbcmtd Wholesale Markets ablaze http://t.co/l...       1
# 49  We always try to bring the heavy. #metal #RT h...       0
# 50  #AFRICANBAZE: Breaking news:Nigeria flag set a...       1
# 52                 Crying out for more! Set me ablaze       0
# 53  On plus side LOOK AT THE SKY LAST NIGHT IT WAS...       0
# 54  @PhDSquares #mufc they've built so much hype a...       0
# 55  INEC Office in Abia Set Ablaze - http://t.co/3...       1
# 56  Barbados #Bridgetown JAMAICA ÛÒ Two cars set ...       1
# 57                             Ablaze for you Lord :D       0
# 59  Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 61  on the outside you're ablaze and alive\nbut yo...       0
# 62  Had an awesome time visiting the CFC head offi...       0
# 63       SOOOO PUMPED FOR ABLAZE ???? @southridgelife       0
# 64  I wanted to set Chicago ablaze with my preachi...       0
# 65  I gained 3 followers in the last week. You? Kn...       0
# 66  How the West was burned: Thousands of wildfire...       1
# 67  Building the perfect tracklist to life leave t...       0
# 68  Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 71  First night with retainers in. It's quite weir...       0
#
#                                               concat
# id
# 1     Our Deeds are the Reason of this #earthquake...
# 4              Forest fire near La Ronge Sask. Canada
# 5     All residents asked to 'shelter in place' ar...
# 6     13,000 people receive #wildfires evacuation ...
# 7     Just got sent this photo from Ruby #Alaska a...
# 8     #RockyFire Update => California Hwy. 20 clos...
# 10    #flood #disaster Heavy rain causes flash flo...
# 13    I'm on top of the hill and I can see a fire ...
# 14    There's an emergency evacuation happening no...
# 15    I'm afraid that the tornado is coming to our...
# 16        Three people died from the heat wave so far
# 17    Haha South Tampa is getting flooded hah- WAI...
# 18    #raining #flooding #Florida #TampaBay #Tampa...
# 19            #Flood in Bago Myanmar #We arrived Bago
# 20    Damage to school bus on 80 in multi car cras...
# 23                                     What's up man?
# 24                                      I love fruits
# 25                                   Summer is lovely
# 26                                  My car is so fast
# 28                       What a goooooooaaaaaal!!!!!!
# 31                             this is ridiculous....
# 32                                  London is cool ;)
# 33                                        Love skiing
# 34                              What a wonderful day!
# 36                                           LOOOOOOL
# 37                     No way...I can't eat that shit
# 38                              Was in NYC last week!
# 39                                 Love my girlfriend
# 40                                          Cooool :)
# 41                                 Do you like pasta?
# 44                                           The end!
# 48  Birmingham ablaze @bbcmtd Wholesale Markets ab...
# 49  Est. September 2012 - Bristol ablaze We always...
# 50  AFRICA ablaze #AFRICANBAZE: Breaking news:Nige...
# 52  Philadelphia, PA ablaze Crying out for more! S...
# 53  London, UK ablaze On plus side LOOK AT THE SKY...
# 54  Pretoria ablaze @PhDSquares #mufc they've buil...
# 55  World Wide!! ablaze INEC Office in Abia Set Ab...
# 56   ablaze Barbados #Bridgetown JAMAICA ÛÒ Two c...
# 57       Paranaque City ablaze Ablaze for you Lord :D
# 59  Live On Webcam ablaze Check these out: http://...
# 61   ablaze on the outside you're ablaze and alive...
# 62  milky way ablaze Had an awesome time visiting ...
# 63   ablaze SOOOO PUMPED FOR ABLAZE ???? @southrid...
# 64   ablaze I wanted to set Chicago ablaze with my...
# 65   ablaze I gained 3 followers in the last week....
# 66  GREENSBORO,NORTH CAROLINA ablaze How the West ...
# 67   ablaze Building the perfect tracklist to life...
# 68  Live On Webcam ablaze Check these out: http://...
# 71  England. ablaze First night with retainers in....
